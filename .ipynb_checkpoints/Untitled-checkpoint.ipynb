# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from matplotlib.collections import PatchCollection
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon
from shapely.prepared import prep
from pysal.esda.mapclassify import Natural_Breaks as nb
from descartes import PolygonPatch
from itertools import chain
# Out:
# D:\program\Anaconda3\envs\py35\lib\site-packages\pysal\__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)

# %%
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution='c',lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# draw coastlines.
m.drawcoastlines()
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.colors import Normalize

# %%
fig, ax = plt.subplots(figsize=(10,20))
#m = Basemap(llcrnrlon = 119.3, llcrnrlat = 20.7, urcrnrlon = 124.6, urcrnrlat = 26,resolution = 'h', epsg = 3415)
m = Basemap(resolution='h', # c, l, i, h, f or Non
            projection='merc',llcrnrlon=-122.450032, llcrnrlat= 47.500582, urcrnrlon=-122.214925, urcrnrlat=47.732752)
m.drawmapboundary(fill_color='aqua')
m.fillcontinents(color='coral',lake_color='aqua')
m.drawcoastlines()
m.readshapefile('https://github.com/seattleio/seattle-boundaries-data/blob/master/data/zip-codes.geojson','properties')
#-122.450032,47.500582,-122.214925,47.732752
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-eb7478d9f302> in <module>
#       6 m.fillcontinents(color='coral',lake_color='aqua')
#       7 m.drawcoastlines()
# ----> 8 m.readshapefile('https://github.com/seattleio/seattle-boundaries-data/blob/master/data/zip-codes.geojson','properties')
#       9 #-122.450032,47.500582,-122.214925,47.732752
#
# D:\program\Anaconda3\envs\py35\lib\site-packages\mpl_toolkits\basemap\__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2132         shp.default_encoding = default_encoding
#    2133         if not os.path.exists('%s.shp'%shapefile):
# -> 2134             raise IOError('cannot locate %s.shp'%shapefile)
#    2135         if not os.path.exists('%s.shx'%shapefile):
#    2136             raise IOError('cannot locate %s.shx'%shapefile)
#
# ...

# %%
import json
with open('https://github.com/seattleio/seattle-boundaries-data/blob/spd/data/zip-codes.geojson') as f:
    data = json.load(f)

for feature in data['features']:
    print (feature['geometry']['type'])
    print (feature['geometry']['coordinates'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-d619eae999b2> in <module>
#       1 import json
# ----> 2 with open('https://github.com/seattleio/seattle-boundaries-data/blob/spd/data/zip-codes.geojson') as f:
#       3     data = json.load(f)
#       4
#       5 for feature in data['features']:
#
# OSError: [Errno 22] Invalid argument: 'https://github.com/seattleio/seattle-boundaries-data/blob/spd/data/zip-codes.geojson'

# %%
import pygeoj
testfile = pygeoj.load('https://raw.githubusercontent.com/seattleio/seattle-boundaries-data/master/data/zip-codes.geojson')
for feature in testfile:
    print (feature.geometry.type)
    print (feature.geometry.coordinates)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-cc85c39539a2> in <module>
#       1 import pygeoj
# ----> 2 testfile = pygeoj.load('https://raw.githubusercontent.com/seattleio/seattle-boundaries-data/master/data/zip-codes.geojson')
#       3 for feature in testfile:
#       4     print (feature.geometry.type)
#       5     print (feature.geometry.coordinates)
#
# D:\program\Anaconda3\envs\py35\lib\site-packages\pygeoj.py in load(filepath, data, **kwargs)
#     789     - A GeojsonFile instance.
#     790     """
# --> 791     return GeojsonFile(filepath, data, **kwargs)
#     792
#     793 def new():
#
# D:\program\Anaconda3\envs\py35\lib\site-packages\pygeoj.py in __init__(self, filepath, data, skiperrors, fixerrors, **kwargs)
#     458
#     459         if filepath:
# --> 460             data = self._loadfilepath(filepath, **kwargs)
# ...
